# %%
healthy_app_seq = "..."

# %%
print(len(healthy_app_seq))
# Out:
# 770

# %%
def replacer(s, newstring, index, nofail=False):
    # raise an error if index is outside of the string
    if not nofail and index not in range(len(s)):
        raise ValueError("index outside given string")

    # if not erroring, but the index is still not in the correct range..
    if index < 0:  # add it to the beginning
        return newstring + s
    if index > len(s):  # add it to the end
        return s + newstring

    # insert the new string between "slices" of the original
    return s[:index] + newstring + s[index + 1:]

# %%
 #A673T
position_1 = 673
# subtract 1 to factor for 0-indexing in Python
mutation_1_seq = replacer(healthy_app_seq, 'T', position_1 - 1)

print(mutation_1_seq)
# Out:
# ...

# %%
# A673V
position_2 = 673
mutation_2_seq = replacer(healthy_app_seq, 'V', position_2 - 1)
print(mutation_2_seq)
# Out:
# ...

# %%
#E682K, E693G, and E693Q
position_3 = 682
mutation_3_seq = replacer(healthy_app_seq, 'K', position_3 - 1)
print(mutation_3_seq)
print(healthy_app_seq[position_3 - 1])
print(mutation_3_seq[position_3 - 1])
# Out:
# ...
# E
# K

# %%
#E693G, and E693Q
position_4 = 693
mutation_4_seq = replacer(healthy_app_seq, 'G', position_4 - 1)
print(mutation_4_seq)
print(healthy_app_seq[position_4 - 1])
print(mutation_4_seq[position_4 - 1])
# Out:
# ...
# E
# G
